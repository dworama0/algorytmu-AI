# %%
import tensorflow as tf
print(f"wersja tf: {tf.__version__}")
# Out:
# wersja tf: 2.10.1

# %%
mnist = tf.keras.datasets.mnist

(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
x_train, x_test  = x_train/255.0, x_test/255.0

# %%
#budowa modelu sieci neuronowych

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 128)               100480
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
#predykcja na niewytrenowanym modelu
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# <pre>array([[-0.3548166 , -0.91262424, -0.50772566,  0.49995905, -0.06027719,
#          0.01569135, -0.22903046,  0.08524667, -0.05110914, -1.1122092 ]],
#       dtype=float32)</pre>

# %%
tf.nn.softmax(predictions).numpy()
# Out:
# <pre>array([[0.08276021, 0.04737714, 0.07102545, 0.1945566 , 0.11110624,
#         0.1198757 , 0.09385336, 0.1285105 , 0.11212955, 0.03880522]],
#       dtype=float32)</pre>

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2937 - accuracy: 0.9139
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1410 - accuracy: 0.9584
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1066 - accuracy: 0.9675
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0858 - accuracy: 0.9734
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0757 - accuracy: 0.9764

# %%
model.evaluate(x_test,y_test,verbose=2)
# Out:
# 313/313 - 1s - loss: 0.0755 - accuracy: 0.9770 - 567ms/epoch - 2ms/step
# [0.0754527673125267, 0.9769999980926514]
